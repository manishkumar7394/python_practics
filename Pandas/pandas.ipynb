# %% [markdown]
# # Panda
#
# #### complex data structure to mimic relational table in python

# %%
## Installion 
#import
import pandas as pd

# %%
list1 = [10,80,30.8,40.0,50,83,60]
print(type(list1))
s= pd.Series(list1)

print(type (s))
print(s)
# Out:
# <class 'list'>
# <class 'pandas.core.series.Series'>
# 0    10.0
# 1    80.0
# 2    30.8
# 3    40.0
# 4    50.0
# 5    83.0
# 6    60.0
# dtype: float64

# %%
## Series vs Dataframe
s2= pd.Series (["Math", "sc","ssc","art","music","eng","hindi"])
print(type(s2))
print(s2)
# Out:
# <class 'pandas.core.series.Series'>
# 0     Math
# 1       sc
# 2      ssc
# 3      art
# 4    music
# 5      eng
# 6    hindi
# dtype: object

# %%
df1 = pd.DataFrame([s,s2])
data = [s,s2]
data
# Out:
# [0    10.0
#  1    80.0
#  2    30.8
#  3    40.0
#  4    50.0
#  5    83.0
#  6    60.0
#  dtype: float64,
#  0     Math
#  1       sc
#  2      ssc
#  3      art
#  4    music
#  5      eng
#  6    hindi
#  dtype: object]

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#       0     1     2     3      4     5      6
# 0  10.0  80.0  30.8  40.0   50.0  83.0   60.0
# 1  Math    sc   ssc   art  music   eng  hindi

# %%
df1 = pd.DataFrame(s,columns= ["Subject1", "Subject2","Subject3","Subject4", "Subject5","Subject6", "Subject7"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1 = pd.DataFrame(s,columns= ["Subject1", "Subject2","Subject3","Subject4", "Subject5","Subject6", "Subject7"])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     820         mgr = dict_to_mgr(
#     821             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     822             # attribute "name"
#    (...)    828             copy=_copy,
#     829         )
#     830     else:
# --> 831         mgr = ndarray_to_mgr(
#     832             data,
#     833             index,
#     834             columns,
#     835             dtype=dtype,
#     836             copy=copy,
#     837             typ=manager,
#     838         )
# ...

# %%
d1 = {
    ["Math":10],
    ["sc": 20],
    ["ssc":30],
    ["arts":50],
    ["eng":70],
    ["hindi": 90]
}
d1
# Out:
#   Cell In[13], line 1
#     d1 = {["Math":10],
#                  ^
# SyntaxError: invalid syntax

# %%
df1= pd.DataFrame(d1)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df1= pd.DataFrame(d1)
#       2 df1
#
# NameError: name 'd1' is not defined

# %%
data =[
    [ "07-Jan-2026",	"Falcons",	"Comets",	"River Court"	," Zara",	"Grade", 6,	22,	29,	1	,3	,4,	2628,	"Coach Maya",	"Win"],
    [ "09-Jan-2026",	"Falcons",  "Comets",	"Central Dome",	"Zara",	"Grade", 5	,35,	12,	11,	14,	1,	2739,	"Coach Maya",	"Loss"]
]

df3 = pd.DataFrame(data,columns=['Match_Date','Team',	'Opponent',	'Venue',	'Player',	'Grade',	
                                 'Minutes_Played',	'Points_Scored',	'Assists',	'Rebounds',	'Fouls',	'Ticket_Sales',	'Coach',	'Match_Result',"extra"])
df3
# Out:
#     Match_Date     Team Opponent         Venue Player  Grade  Minutes_Played  \
# 0  07-Jan-2026  Falcons   Comets   River Court   Zara  Grade               6
# 1  09-Jan-2026  Falcons   Comets  Central Dome   Zara  Grade               5
#
#    Points_Scored  Assists  Rebounds  Fouls  Ticket_Sales  Coach Match_Result  \
# 0             22       29         1      3             4   2628   Coach Maya
# 1             35       12        11     14             1   2739   Coach Maya
#
#   extra
# 0   Win
# 1  Loss

# %%
df4=pd.read_csv('/Users/manish/Downloads/apple_products_pricing_2020_2026.csv')
df4
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
data = pd.read_excel('/Users/manish/Downloads/customer_churn_data_raw.xlsx')
data
# Out:
#     customerid        name country          state  gender        dob  \
# 0   0002-ORFBO      keshav   India    Maharashtra    Male 1982-04-12
# 1   0003-MKNFE      raghav   India      Karnataka    Male 1995-11-23
# 2   0004-TLHLJ      lalita   India          Delhi  Female 1978-02-15
# 3   0011-IGKFF       mohan   India       Nagaland    Male 2001-08-30
# 4   0013-EXCHZ        mira   India          Delhi  Female 1990-05-05
# 5   0013-MHZWF       durga     NaN          Delhi   Women 1988-12-10
# 6   0013-SMEOE        mina   India      Meghalaya  Female 1976-09-21
# 7   0014-BMAQU       madan   India      Rajasthan    Male 1999-03-14
# 8   0015-UOCOJ        maya     NaN      Kathmandu   Women 1985-07-07
# 9   0016-QLJIS       arjun   Nepal      Kathmandu    Male 1993-10-29
# 10  0017-DINOC       shiva   India    Maharashtra     Men 1997-01-22
# 11  0017-IUDMW   rangadevi   India      Karnataka  Female 1981-06-18
# 12  0018-NYROU      chitra     NaN      Telangana  Female 2004-12-01
# ...

# %%
## Summary stats using NumPy

import numpy as np

data = np.array(df4[df4.columns[6]][:39])

print(f"Count      : {data.size}")
print(f"Mean       : {np.mean(data):.2f}")
print(f"Median     : {np.median(data):.2f}")
print(f"Std (pop)  : {np.std(data):.2f}")              # Default: ddof=0 (population)
print(f"Std (sam)  : {np.std(data, ddof=1):.2f}")      # ddof=1 for sample
print(f"Var (pop)  : {np.var(data):.2f}")
print(f"Min        : {np.min(data)}")
print(f"Max        : {np.max(data)}")
print(f"Sum        : {np.sum(data)}")

# Percentiles
print(f"25th pctile: {np.percentile(data, 25):.2f}")
print(f"50th pctile: {np.percentile(data, 50):.2f}")   # Same as median
print(f"75th pctile: {np.percentile(data, 75):.2f}")
print(f"90th pctile: {np.percentile(data, 90):.2f}")
# Out:
# Count      : 39
# Mean       : 44831.23
# Median     : 42042.00
# Std (pop)  : 10632.88
# Std (sam)  : 10771.88
# Var (pop)  : 113058212.23
# Min        : 42042
# Max        : 97902
# Sum        : 1748418
# 25th pctile: 42042.00
# 50th pctile: 42042.00
# 75th pctile: 42042.00
# 90th pctile: 42042.00

# %%
df4.tail()
# Out:
#              Date  Platform Product_Category       Model_Name  \
# 79995  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone  iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# 79995                  New               849             83202
# 79996                  New               849             83202
# 79997  Renewed/Refurbished               849             83202
# 79998  Renewed/Refurbished               849             83202
# 79999                  New               849             83202
#
#        Current_Price_USD  Current_Price_INR  Discount_Pct Sale_Event  \
# 79995             861.39           82894.76          -1.5        NaN
# 79996             832.50           81159.39           1.9        NaN
# ...

# %%
df5 = df4[:40][:]
df5
# Out:
#           Date  Platform Product_Category                   Model_Name  \
# 0   2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1   2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2   2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3   2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4   2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# 5   2020-09-26  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 6   2020-09-27  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 7   2020-09-29  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 8   2020-10-01  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 9   2020-10-01    Amazon            Watch  Apple Watch Series 6 (44mm)
# 10  2020-10-01    Amazon            Watch  Apple Watch Series 6 (44mm)
# 11  2020-10-01    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...

# %%
df4.head(5)
# Out:
#          Date  Platform Product_Category                   Model_Name  \
# 0  2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1  2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4  2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
#
#   Condition  Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# 0       New               429             42042             435.81
# 1       New               429             42042             436.49
# 2       New               429             42042             422.73
# 3       New               429             42042             425.00
# 4       New               429             42042             436.22
#
#    Current_Price_INR  Discount_Pct Sale_Event  Stock_Status  Rating  \
# 0           43322.41          -1.6        NaN      In Stock     4.7
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               80000 non-null  object
#  1   Platform           80000 non-null  object
#  2   Product_Category   80000 non-null  object
#  3   Model_Name         80000 non-null  object
#  4   Condition          80000 non-null  object
#  5   Launch_Price_USD   80000 non-null  int64
#  6   Launch_Price_INR   80000 non-null  int64
#  7   Current_Price_USD  80000 non-null  float64
#  8   Current_Price_INR  80000 non-null  float64
#  9   Discount_Pct       80000 non-null  float64
#  10  Sale_Event         6649 non-null   object
#  11  Stock_Status       80000 non-null  object
#  12  Rating             80000 non-null  float64
#  13  Reviews_Count      80000 non-null  int64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 8.5+ MB

# %%
df4.describe
# Out:
# <bound method NDFrame.describe of              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
# ...
